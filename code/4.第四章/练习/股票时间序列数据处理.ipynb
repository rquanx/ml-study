# %%
import pandas as pd

dff = pd.read_csv("./GOOGL.csv")

dff.head(15)
# Out:
#          Date        Open        High  ...       Close   Adj Close    Volume
# 0    2005/1/3   98.798798  101.921921  ...  101.456459  101.456459  31656700
# 1    2005/1/4  100.800804  101.566566  ...   97.347351   97.347351  27484200
# 2    2005/1/5   96.821823   98.548546  ...   96.851852   96.851852  16456700
# 3    2005/1/6   97.637634   98.048050  ...   94.369370   94.369370  20753400
# 4    2005/1/7   95.415413   97.222221  ...   97.022018   97.022018  19306400
# 5   2005/1/10   97.347351   99.149147  ...   97.627625   97.627625  15064100
# 6   2005/1/11   97.907906   98.953957  ...   96.866867   96.866867  13903400
# 7   2005/1/12   97.262260   98.063065  ...   97.787788   97.787788  16339200
# 8   2005/1/13   97.787788   98.793793  ...   97.762764   97.762764  13685100
# 9   2005/1/14   98.098099  100.105103  ...  100.085083  100.085083  19261300
# 10  2005/1/18  100.585587  102.612610  ...  102.052055  102.052055  26318800
# ...

# %%
# import datetime
# import numpy as np


# def date_to_datetime(date_str):
#     return datetime.datetime.strptime(date_str, "%Y/%m/%d")

# def calc_mean(lines,key):
#     mean_values = np.mean(lines, axis=0)
#     insert = np.insert(mean_values,0,key)
#     return insert


# def quarter_volume():
#     columns = dff.columns.tolist()
#     date_column = columns.index("Date")
#     data = np.array(dff.values)
#     # np.argsort([date_to_datetime(date) for date in data[:, date_column]])[::-1]  从大到小
#     sort_index = np.argsort([date_to_datetime(date) for date in data[:, date_column]])

#     # 遍历所有行的 date_column 列进行转换
#     # date_to_datetime(date) for date in data[:, date_column]
#     # np.argsort 从小到大排序后的索引数组
#     # sorted_data = data[[xxx]] #  np.array 可以根据索引重新排序
#     sorted_data = data[sort_index]
#     min_date = date_to_datetime(sorted_data[0][date_column])
#     max_date = date_to_datetime(sorted_data[-1][date_column])
#     new_data = []
#     d = []
#     prev_key = ""
#     key = ""
#     for line in sorted_data:
#         date = date_to_datetime(line[date_column])
#         year = date.year
#         month = date.month
#         if month <= 3:
#             key = f"{year}-第一季度"
#         elif month <= 6:
#             key = f"{year}-第二季度"
#         elif month <= 9:
#             key = f"{year}-第三季度"
#         else:
#             key = f"{year}-第四季度"
#         if prev_key != key:
#             if len(d) > 0:
#                 l = calc_mean(d,prev_key)
#                 new_data.append(l)
#             prev_key = key
#             d = []
#         l = np.delete(line.copy(),date_column)
#         d.append(l)
#     l = calc_mean(d,key)
#     new_data.append(l)
#     return pd.DataFrame(new_data, columns=dff.columns)  # 返回题目要求的 DataFrame


# quarter_volume()
# Out:
#          Date         Open         High  ...        Close    Adj Close        Volume
# 0   2005-第一季度    95.061947    96.312952  ...    94.747699    94.747699  2.301703e+07
# 1   2005-第二季度   121.146146   122.896256  ...   121.554523   121.554523  2.714345e+07
# 2   2005-第三季度   148.090590   149.723786  ...   148.214620   148.214620  1.617358e+07
# 3   2005-第四季度   190.464512   192.353543  ...   190.283220   190.283220  1.913668e+07
# 4   2006-第一季度   195.894927   198.766912  ...   195.342278   195.342278  2.911046e+07
# 5   2006-第二季度   198.767022   201.024517  ...   198.328011   198.328011  1.597237e+07
# 6   2006-第三季度   196.440806   198.137106  ...   196.108570   196.108570  1.129168e+07
# 7   2006-第四季度   233.356134   235.595436  ...   233.248963   233.248963  1.169042e+07
# 8   2007-第一季度   235.389734   237.606131  ...   235.094192   235.094192  1.168064e+07
# 9   2007-第二季度   243.560783   245.710551  ...   243.669384   243.669384  1.019890e+07
# ...

# %%
def quarter_volume1():
    # 读取数据，并且以第一列作为索引，不要默认的 1、2、3.....了
    df = pd.read_csv("GOOGL.csv", index_col=0)
    df.index = pd.to_datetime(df.index)
    df = df.resample('Q').agg({"Open": 'mean', "High": 'mean', "Low": 'mean',
                               "Close": 'mean', "Adj Close": 'mean', "Volume": 'sum'})
    # 按 Volume 排序
    df = df.sort_values(by='Volume', ascending=False)
    return df

# %%
quarter_volume1()
# Out:
# DatetimeIndex(['2005-01-03', '2005-01-04', '2005-01-05', '2005-01-06',
#                '2005-01-07', '2005-01-10', '2005-01-11', '2005-01-12',
#                '2005-01-13', '2005-01-14',
#                ...
#                '2017-12-15', '2017-12-18', '2017-12-19', '2017-12-20',
#                '2017-12-21', '2017-12-22', '2017-12-26', '2017-12-27',
#                '2017-12-28', '2017-12-29'],
#               dtype='datetime64[ns]', name='Date', length=3272, freq=None)
# C:\Users\91658\AppData\Local\Temp\ipykernel_85524\1620123924.py:5: FutureWarning: 'Q' is deprecated and will be removed in a future version, please use 'QE' instead.
#   df = df.resample('Q').agg({"Open": 'mean', "High": 'mean', "Low": 'mean',
#                    Open         High  ...    Adj Close      Volume
# Date                                  ...
# 2006-03-31   195.894927   198.766912  ...   195.342278  1804848300
# 2005-06-30   121.146146   122.896256  ...   121.554523  1737181000
# ...
